# %%
import os, time, pickle
import numpy as np
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
from collections import defaultdict

# %%
SELENIUM_PATH = 'C:\\GIT\\SELENIUM_DRIVERS\\chromedriver_win32\\chromedriver'

# %%
def load_driver(chrome_driver_filepath):
    options = webdriver.ChromeOptions()
    options.add_argument('headless')
    driver = webdriver.Chrome(chrome_driver_filepath, chrome_options=options)
    driver.implicitly_wait(3)
    return driver

def read_options(driver):
    institution_option_values = []
    driver.get('https://www.bis.org/cbspeeches/')
    select = Select(driver.find_element_by_id('cbspeeches_institutions_filter'))
    options = driver.find_element_by_id('cbspeeches_institutions_filter').find_elements_by_tag_name("option")

    for option in options:
        content = option.get_attribute('outerHTML')
        content_name = option.get_attribute('innerHTML').strip()

        left_txt = '<option value="'
        right_txt = '">'
        option_value = content[content.index(left_txt)+len(left_txt):content.index(right_txt)]
        
        institution_option_values.append((option_value, content_name))
        
    country_option_values = []
    driver.get('https://www.bis.org/cbspeeches/')
    select = Select(driver.find_element_by_id('cbspeeches_countries_filter'))
    options = driver.find_element_by_id('cbspeeches_countries_filter').find_elements_by_tag_name("option")

    for option in options:
        content = option.get_attribute('outerHTML')
        content_name = option.get_attribute('innerHTML').strip()

        left_txt = '<option value="'
        right_txt = '">'
        option_value = content[content.index(left_txt)+len(left_txt):content.index(right_txt)]
        
        country_option_values.append((option_value, content_name))
    
    return institution_option_values, country_option_values

def get_soup(driver):
    try: soup = BeautifulSoup(driver.page_source, "html.parser")
    except: soup = BeautifulSoup(driver.page_source, "lxml")
    return soup

def pick_txt(left_text, right_text, content):
    return content[content.index(left_txt)+len(left_txt):content.index(right_txt)].strip()

def sleep_(config_sleep=3, random=True):
    if random:
        sleeptime = np.random.randint(1,10)*0.3*config_sleep
    else:
        sleeptime = config_sleep
    print('sleep ', sleeptime)
    time.sleep(sleeptime)

# %%
driver = load_driver(SELENIUM_PATH)
institution_option_values, country_option_values = read_options(driver)
# Out:
# <ipython-input-3-df4c947d9b20>:4: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_driver_filepath, chrome_options=options)

# %%
institution_option_values = [item for item in institution_option_values if 'Federal' in item[1]]
institution_option_values
# Out:
# [('24', 'Board of Governors of the Federal Reserve System'),
#  ('95', 'Federal Reserve Bank of Atlanta'),
#  ('88', 'Federal Reserve Bank of Boston'),
#  ('96', 'Federal Reserve Bank of Chicago'),
#  ('263', 'Federal Reserve Bank of Dallas'),
#  ('85', 'Federal Reserve Bank of Kansas City'),
#  ('101', 'Federal Reserve Bank of Minneapolis'),
#  ('22', 'Federal Reserve Bank of New York'),
#  ('99', 'Federal Reserve Bank of Philadelphia'),
#  ('100', 'Federal Reserve Bank of Richmond'),
#  ('105', 'Federal Reserve Bank of San Francisco')]

# %%
item_dict = dict()
visited_dict = defaultdict(int)

# institution
for option_value, institution_name in institution_option_values:
    print('Processing', institution_name)

    driver.get('https://www.bis.org/cbspeeches/')
    select = Select(driver.find_element_by_id('cbspeeches_institutions_filter'))
    select.select_by_value(option_value)

    try:
        driver.find_element_by_css_selector('#cbspeeches_list > div > div.navigation.page_nav_bottom > nav > div > div:nth-child(2) > div > div:nth-child(3) > div > a').click()
        driver.find_element_by_css_selector('#cbspeeches_list > div > div.navigation.page_nav_bottom > nav > div > div:nth-child(2) > div > div:nth-child(1) > div > a').click()
    except: 
        driver.get('https://www.bis.org/cbspeeches/')
        select = Select(driver.find_element_by_id('cbspeeches_institutions_filter'))
        select.select_by_value(option_value)
        
        soup = get_soup(driver)
        a_list = soup.select("table.documentList tr a.dark")
        for a_element in a_list:
            id_value = a_element['href'].split('/')[-1][:-4]
            item_dict[id_value] = [institution_name]

        print('[{}] '.format(len(item_dict)))
        continue
        
    while True:    
        sleep_(config_sleep=5)
        pageof = driver.find_element_by_css_selector('div.pageof').get_attribute('innerHTML')
        print(pageof, end=' ')
        visited_dict[pageof] += 1
        if visited_dict[pageof] >= 3: break
            
        soup = get_soup(driver)
        a_list = soup.select("table.documentList tr a.dark")
        for a_element in a_list:
            id_value = a_element['href'].split('/')[-1][:-4]
            item_dict[id_value] = [institution_name]

        print('[{}] '.format(len(item_dict)))

        try: driver.find_element_by_css_selector('#cbspeeches_list > div > div.navigation.page_nav_bottom > nav > div > div:nth-child(2) > div > div:nth-child(3) > div > a').click()
        except:
            try:
                navs = soup.select('a.navcarot')
                if len(navs) == 2:
                    next_url = "https://www.bis.org/cbspeeches/" + navs[-1]['href']
                    driver.get(next_url)
            except: break
# Out:
# Processing Board of Governors of the Federal Reserve System
# sleep  7.5
# Page <span style="font-weight:600;">1 of 73</span> [10]
# sleep  3.0
# Page <span style="font-weight:600;">2 of 73</span> [20]
# sleep  4.5
# Page <span style="font-weight:600;">3 of 73</span> [30]
# sleep  7.5
# Page <span style="font-weight:600;">4 of 73</span> [40]
# sleep  6.0
# Page <span style="font-weight:600;">5 of 73</span> [50]
# sleep  1.5
# Page <span style="font-weight:600;">6 of 73</span> [60]
# sleep  12.0
# Page <span style="font-weight:600;">7 of 73</span> [70]
# sleep  3.0
# Page <span style="font-weight:600;">8 of 73</span> [80]
# sleep  7.5
# Page <span style="font-weight:600;">9 of 73</span> [90]
# sleep  3.0
# Page <span style="font-weight:600;">10 of 73</span> [100]
# sleep  7.5
# Page <span style="font-weight:600;">11 of 73</span> [110]
# sleep  1.5
# Page <span style="font-weight:600;">12 of 73</span> [120]
# sleep  10.5
# Page <span style="font-weight:600;">13 of 73</span> [130]
# sleep  9.0
# Page <span style="font-weight:600;">14 of 73</span> [140]
# sleep  1.5
# Page <span style="font-weight:600;">15 of 73</span> [150]
# sleep  9.0
# Page <span style="font-weight:600;">16 of 73</span> [160]
# sleep  6.0
# Page <span style="font-weight:600;">17 of 73</span> [170]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">18 of 73</span> [180]
# sleep  6.0
# Page <span style="font-weight:600;">19 of 73</span> [190]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">20 of 73</span> [200]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">21 of 73</span> [210]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">22 of 73</span> [220]
# sleep  7.5
# Page <span style="font-weight:600;">23 of 73</span> [230]
# sleep  9.0
# Page <span style="font-weight:600;">24 of 73</span> [240]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">25 of 73</span> [250]
# sleep  7.5
# Page <span style="font-weight:600;">26 of 73</span> [260]
# sleep  1.5
# Page <span style="font-weight:600;">27 of 73</span> [270]
# sleep  1.5
# Page <span style="font-weight:600;">28 of 73</span> [280]
# sleep  6.0
# Page <span style="font-weight:600;">29 of 73</span> [290]
# sleep  4.5
# Page <span style="font-weight:600;">30 of 73</span> [300]
# sleep  12.0
# Page <span style="font-weight:600;">31 of 73</span> [310]
# sleep  3.0
# Page <span style="font-weight:600;">32 of 73</span> [320]
# sleep  9.0
# Page <span style="font-weight:600;">33 of 73</span> [330]
# sleep  6.0
# Page <span style="font-weight:600;">34 of 73</span> [340]
# sleep  7.5
# Page <span style="font-weight:600;">35 of 73</span> [350]
# sleep  3.0
# Page <span style="font-weight:600;">36 of 73</span> [360]
# sleep  3.0
# Page <span style="font-weight:600;">37 of 73</span> [370]
# sleep  1.5
# Page <span style="font-weight:600;">38 of 73</span> [380]
# sleep  10.5
# Page <span style="font-weight:600;">39 of 73</span> [390]
# sleep  10.5
# Page <span style="font-weight:600;">40 of 73</span> [400]
# sleep  3.0
# Page <span style="font-weight:600;">41 of 73</span> [410]
# sleep  12.0
# Page <span style="font-weight:600;">42 of 73</span> [420]
# sleep  4.5
# Page <span style="font-weight:600;">43 of 73</span> [430]
# sleep  4.5
# Page <span style="font-weight:600;">44 of 73</span> [440]
# sleep  6.0
# Page <span style="font-weight:600;">45 of 73</span> [450]
# sleep  4.5
# Page <span style="font-weight:600;">46 of 73</span> [460]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">47 of 73</span> [470]
# sleep  7.5
# Page <span style="font-weight:600;">48 of 73</span> [480]
# sleep  6.0
# Page <span style="font-weight:600;">49 of 73</span> [490]
# sleep  10.5
# Page <span style="font-weight:600;">50 of 73</span> [500]
# sleep  6.0
# Page <span style="font-weight:600;">51 of 73</span> [510]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">52 of 73</span> [520]
# sleep  3.0
# Page <span style="font-weight:600;">53 of 73</span> [530]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">54 of 73</span> [540]
# sleep  7.5
# Page <span style="font-weight:600;">55 of 73</span> [550]
# sleep  6.0
# Page <span style="font-weight:600;">56 of 73</span> [560]
# sleep  12.0
# Page <span style="font-weight:600;">57 of 73</span> [570]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">58 of 73</span> [580]
# sleep  4.5
# Page <span style="font-weight:600;">59 of 73</span> [590]
# sleep  10.5
# Page <span style="font-weight:600;">60 of 73</span> [600]
# sleep  4.5
# Page <span style="font-weight:600;">61 of 73</span> [610]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">62 of 73</span> [620]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">63 of 73</span> [630]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">64 of 73</span> [640]
# sleep  6.0
# Page <span style="font-weight:600;">65 of 73</span> [650]
# sleep  10.5
# Page <span style="font-weight:600;">66 of 73</span> [660]
# sleep  3.0
# Page <span style="font-weight:600;">67 of 73</span> [670]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">68 of 73</span> [680]
# sleep  1.5
# Page <span style="font-weight:600;">69 of 73</span> [690]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">70 of 73</span> [700]
# sleep  6.0
# Page <span style="font-weight:600;">71 of 73</span> [710]
# sleep  7.5
# Page <span style="font-weight:600;">72 of 73</span> [720]
# sleep  1.5
# Page <span style="font-weight:600;">73 of 73</span> [723]
# sleep  3.0
# Page <span style="font-weight:600;">73 of 73</span> [723]
# sleep  1.5
# Page <span style="font-weight:600;">73 of 73</span> Processing Federal Reserve Bank of Atlanta
# [723]
# Processing Federal Reserve Bank of Boston
# [723]
# Processing Federal Reserve Bank of Chicago
# [723]
# Processing Federal Reserve Bank of Dallas
# sleep  9.0
# Page <span style="font-weight:600;">1 of 2</span> [733]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">2 of 2</span> [742]
# sleep  7.5
# Page <span style="font-weight:600;">2 of 2</span> [742]
# sleep  12.0
# Page <span style="font-weight:600;">2 of 2</span> Processing Federal Reserve Bank of Kansas City
# sleep  9.0
# Page <span style="font-weight:600;">1 of 2</span> [752]
# sleep  7.5
# Page <span style="font-weight:600;">2 of 2</span> Processing Federal Reserve Bank of Minneapolis
# sleep  12.0
# Page <span style="font-weight:600;">1 of 3</span> [762]
# sleep  10.5
# Page <span style="font-weight:600;">2 of 3</span> [772]
# sleep  4.5
# Page <span style="font-weight:600;">3 of 3</span> [775]
# sleep  3.0
# Page <span style="font-weight:600;">3 of 3</span> [775]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">3 of 3</span> Processing Federal Reserve Bank of New York
# sleep  9.0
# Page <span style="font-weight:600;">1 of 31</span> [785]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">2 of 31</span> [795]
# sleep  1.5
# Page <span style="font-weight:600;">3 of 31</span> [805]
# sleep  3.0
# Page <span style="font-weight:600;">4 of 31</span> [815]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">5 of 31</span> [825]
# sleep  10.5
# Page <span style="font-weight:600;">6 of 31</span> [835]
# sleep  3.0
# Page <span style="font-weight:600;">7 of 31</span> [845]
# sleep  7.5
# Page <span style="font-weight:600;">8 of 31</span> [855]
# sleep  1.5
# Page <span style="font-weight:600;">9 of 31</span> [865]
# sleep  4.5
# Page <span style="font-weight:600;">10 of 31</span> [875]
# sleep  10.5
# Page <span style="font-weight:600;">11 of 31</span> [885]
# sleep  7.5
# Page <span style="font-weight:600;">12 of 31</span> [895]
# sleep  12.0
# Page <span style="font-weight:600;">13 of 31</span> [905]
# sleep  4.5
# Page <span style="font-weight:600;">14 of 31</span> [915]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">15 of 31</span> [925]
# sleep  1.5
# Page <span style="font-weight:600;">16 of 31</span> [935]
# sleep  4.5
# Page <span style="font-weight:600;">17 of 31</span> [945]
# sleep  6.0
# Page <span style="font-weight:600;">18 of 31</span> [955]
# sleep  7.5
# Page <span style="font-weight:600;">19 of 31</span> [965]
# sleep  4.5
# Page <span style="font-weight:600;">20 of 31</span> [975]
# sleep  3.0
# Page <span style="font-weight:600;">21 of 31</span> [985]
# sleep  7.5
# Page <span style="font-weight:600;">22 of 31</span> [995]
# sleep  12.0
# Page <span style="font-weight:600;">23 of 31</span> [1005]
# sleep  7.5
# Page <span style="font-weight:600;">24 of 31</span> [1015]
# sleep  4.5
# Page <span style="font-weight:600;">25 of 31</span> [1025]
# sleep  4.5
# Page <span style="font-weight:600;">26 of 31</span> [1035]
# sleep  10.5
# Page <span style="font-weight:600;">27 of 31</span> [1045]
# sleep  9.0
# Page <span style="font-weight:600;">28 of 31</span> [1055]
# sleep  6.0
# Page <span style="font-weight:600;">29 of 31</span> [1065]
# sleep  10.5
# Page <span style="font-weight:600;">30 of 31</span> [1075]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">31 of 31</span> [1084]
# sleep  9.0
# Page <span style="font-weight:600;">31 of 31</span> [1084]
# sleep  6.0
# Page <span style="font-weight:600;">31 of 31</span> Processing Federal Reserve Bank of Philadelphia
# sleep  6.0
# Page <span style="font-weight:600;">1 of 4</span> [1094]
# sleep  4.5
# Page <span style="font-weight:600;">2 of 4</span> [1104]
# sleep  3.0
# Page <span style="font-weight:600;">3 of 4</span> [1114]
# sleep  13.499999999999998
# Page <span style="font-weight:600;">4 of 4</span> [1116]
# sleep  1.5
# Page <span style="font-weight:600;">4 of 4</span> [1116]
# sleep  3.0
# Page <span style="font-weight:600;">4 of 4</span> Processing Federal Reserve Bank of Richmond
# [1116]
# Processing Federal Reserve Bank of San Francisco
# [1116]

# %%
with open('item_dict_Federal.pkl', 'wb') as f:
    pickle.dump(item_dict, f)
